# %% [markdown]
# # MATPLOTLIB

# %% [markdown]
# Acervo de funções utéis, explicações e lembretes referentes a essa lib.

# %% [markdown]
# ![Screen%20Shot%202022-03-03%20at%2017.38.21.png](attachment:Screen%20Shot%202022-03-03%20at%2017.38.21.png)

# %% [markdown]
# ### Pyplot Method

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,3,4])
plt.show()

# %%
plt.plot([1,2,3,4], "ro")
plt.show()

# %%
import numpy as np ##para usar as funçoes trigonometricas

x = np.arange(0,10,0.1)
fig1,f1_axes = plt.subplots(ncols=2, nrows=2,figsize=(15,10))
fig1.suptitle("Primeira Figura", size=30)

f1_axes[0,0].plot(np.sin(x), label="sen(x)", color="purple")
f1_axes[0,0].plot(np.cos(x), label="cos(x)", color="darkturquoise")
f1_axes[0,0].set_title("Caixa 1")
f1_axes[0,0].set_xlabel("Caixa 1 - Label x")
f1_axes[0,0].set_ylabel("Caixa 1 - Label y")


f1_axes[0,1].plot(np.cos(x))
f1_axes[0,1].set_title("Caixa 2")

f1_axes[1,0].plot(np.tan(x), label="tan(x)", color="orange")
f1_axes[1,0].set_title("Caixa 3")
# Out:
# Text(0.5, 1.0, 'Caixa 3')

# %%
np.sin? ##help do jupyter
